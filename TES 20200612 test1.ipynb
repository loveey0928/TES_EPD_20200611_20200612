# %%
import plotly.express as px
import pandas as pd

# %%
data00 = pd.read_csv('C:/Users/com/Desktop/TES종합/TES20200612test1.csv')
df_20200611_1_0_EPD = pd.DataFrame(data00[['index','1_0_777','1_0.1_777','1_0.3_777','1_0.6_777']])

fig = px.line(df_20200611_1_0_EPD, x="index", y=["1_0_777", "1_0.1_777","1_0.3_777","1_0.6_777"], title="20200612 test1 777 종합")
fig.show()
# Out:
# <div>
#
#
#             <div id="34fb1901-237f-400f-8329-631afa64cd23" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("34fb1901-237f-400f-8329-631afa64cd23")) {
#                     Plotly.newPlot(
#                         '34fb1901-237f-400f-8329-631afa64cd23',
# ...

# %%
data00 = pd.read_csv('C:/Users/com/Desktop/TES종합/TES20200612test1.csv')
df_20200611_1_0_EPD = pd.DataFrame(data00[['index','1_0_560','1_0.1_560','1_0.3_560','1_0.6_560']])

fig = px.line(df_20200611_1_0_EPD, x="index", y=["1_0_560", "1_0.1_560","1_0.3_560","1_0.6_560"], title="20200612 test1 560 종합")
fig.show()
# Out:
# <div>
#
#
#             <div id="2fbb4345-00e1-4a93-866f-1dab544e5155" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2fbb4345-00e1-4a93-866f-1dab544e5155")) {
#                     Plotly.newPlot(
#                         '2fbb4345-00e1-4a93-866f-1dab544e5155',
# ...

# %%
data5 = pd.read_csv('C:/Users/com/Desktop/2020-06-12 TES OES CSV/2020-06-12_14h58m13s_test1_1_0__condition same as yesterday just change temp to 650.f_oes.csv')
df_20200612_test1_1_0_EPD = pd.DataFrame(data5[['Time(sec)_','560.11','777.013']])

fig = px.line(df_20200612_test1_1_0_EPD, x="Time(sec)_", y=["560.11", "777.013"], title="20200612_test1_1_0_EPD")
fig.show()
# Out:
# <div>
#
#
#             <div id="dcc15789-12ee-478c-8658-c486f56693de" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dcc15789-12ee-478c-8658-c486f56693de")) {
#                     Plotly.newPlot(
#                         'dcc15789-12ee-478c-8658-c486f56693de',
# ...

# %%
data6 = pd.read_csv('C:/Users/com/Desktop/2020-06-12 TES OES CSV/2020-06-12_15h20m04s_test2_1_0.1__condition same as yesterday just change temp to 650.f_oes.csv')
df_20200612_test2_1_01_EPD = pd.DataFrame(data6[['Time(sec)_','560.11','777.013']])

fig = px.line(df_20200612_test2_1_01_EPD, x="Time(sec)_", y=["560.11", "777.013"], title="20200612_test2_1_0.1_EPD")
fig.show()
# Out:
# <div>
#
#
#             <div id="62dd2a93-b4ee-4466-8a26-07e66fc5f948" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("62dd2a93-b4ee-4466-8a26-07e66fc5f948")) {
#                     Plotly.newPlot(
#                         '62dd2a93-b4ee-4466-8a26-07e66fc5f948',
# ...

# %%
data7 = pd.read_csv('C:/Users/com/Desktop/2020-06-12 TES OES CSV/2020-06-12_15h28m36s_test3_1_0.3__condition same as yesterday just change temp to 650.f_oes.csv')
df_20200612_test3_1_03_EPD = pd.DataFrame(data7[['Time(sec)_','560.11','777.013']])

fig = px.line(df_20200612_test3_1_03_EPD, x="Time(sec)_", y=["560.11", "777.013"], title="20200612_test3_1_0.3_EPD")
fig.show()
# Out:
# <div>
#
#
#             <div id="3c736609-71b9-4728-9f9f-2e7f56dd2e7c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3c736609-71b9-4728-9f9f-2e7f56dd2e7c")) {
#                     Plotly.newPlot(
#                         '3c736609-71b9-4728-9f9f-2e7f56dd2e7c',
# ...

# %%
data8 = pd.read_csv('C:/Users/com/Desktop/2020-06-12 TES OES CSV/2020-06-12_15h37m07s_test4_1_0.6__condition same as yesterday just change temp to 650.f_oes.csv')
df_20200612_test4_1_06_EPD = pd.DataFrame(data8[['Time(sec)_','560.11','777.013']])

fig = px.line(df_20200612_test4_1_06_EPD, x="Time(sec)_", y=["560.11", "777.013"], title="20200612_test4_1_0.6_EPD")
fig.show()
# Out:
# <div>
#
#
#             <div id="6a2af4f8-ea72-4b5d-95aa-ff24df347d43" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6a2af4f8-ea72-4b5d-95aa-ff24df347d43")) {
#                     Plotly.newPlot(
#                         '6a2af4f8-ea72-4b5d-95aa-ff24df347d43',
# ...
