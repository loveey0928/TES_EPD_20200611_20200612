# %%
import plotly.express as px
import pandas as pd

# %%
data0 = pd.read_csv('C:/Users/com/Desktop/TES종합/TES20200612test2.csv')
df_20200611_1_0_EPD = pd.DataFrame(data0[['index','1_0_777','1_0.1_777','1_0.3_777','1_0.6_777']])

fig = px.line(df_20200611_1_0_EPD, x="index", y=["1_0_777", "1_0.1_777","1_0.3_777","1_0.6_777"], title="20200612 test2 777 종합")
fig.show()
# Out:
# <div>
#
#
#             <div id="c1b14a77-aac5-4cc3-bc4a-5fbc429925d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c1b14a77-aac5-4cc3-bc4a-5fbc429925d3")) {
#                     Plotly.newPlot(
#                         'c1b14a77-aac5-4cc3-bc4a-5fbc429925d3',
# ...

# %%
data00 = pd.read_csv('C:/Users/com/Desktop/TES종합/TES20200612test2.csv')
df_20200611_1_0_EPD = pd.DataFrame(data00[['index','1_0_560','1_0.1_560','1_0.3_560','1_0.6_560']])

fig = px.line(df_20200611_1_0_EPD, x="index", y=["1_0_560", "1_0.1_560","1_0.3_560","1_0.6_560"], title="20200612 test2 560 종합")
fig.show()
# Out:
# <div>
#
#
#             <div id="8b238deb-ee7d-4d34-8b69-c984c71bbb4d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8b238deb-ee7d-4d34-8b69-c984c71bbb4d")) {
#                     Plotly.newPlot(
#                         '8b238deb-ee7d-4d34-8b69-c984c71bbb4d',
# ...

# %%
data9 = pd.read_csv('C:/Users/com/Desktop/2020-06-12 TES OES CSV/2020-06-12_15h45m38s_test5_1_0__condition changed and temp 650.f_oes.csv')
df_20200612_test6_1_01_EPD = pd.DataFrame(data9[['Time(sec)_','560.11','777.013']])

fig = px.line(df_20200612_test6_1_01_EPD, x="Time(sec)_", y=["560.11", "777.013"], title="20200612_test6_1_0_EPD")
fig.show()
# Out:
# <div>
#
#
#             <div id="33849d4f-9a28-4d0e-9d80-92c388e3f0d8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("33849d4f-9a28-4d0e-9d80-92c388e3f0d8")) {
#                     Plotly.newPlot(
#                         '33849d4f-9a28-4d0e-9d80-92c388e3f0d8',
# ...

# %%
data10 = pd.read_csv('C:/Users/com/Desktop/2020-06-12 TES OES CSV/2020-06-12_15h57m30s_test6_1_0.1__condition changed and temp 650.f_oes.csv')
df_20200612_test6_1_01_EPD = pd.DataFrame(data10[['Time(sec)_','560.11','777.013']])

fig = px.line(df_20200612_test6_1_01_EPD, x="Time(sec)_", y=["560.11", "777.013"], title="20200612_test6_1_0.1_EPD")
fig.show()
# Out:
# <div>
#
#
#             <div id="f978bf6b-3c8e-490f-aa0a-bd3d0fa7316c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f978bf6b-3c8e-490f-aa0a-bd3d0fa7316c")) {
#                     Plotly.newPlot(
#                         'f978bf6b-3c8e-490f-aa0a-bd3d0fa7316c',
# ...

# %%
data11 = pd.read_csv('C:/Users/com/Desktop/2020-06-12 TES OES CSV/2020-06-12_16h09m29s_test7_1_0.3__condition changed and temp 650.f_oes.csv')
df_20200612_test7_1_03_EPD = pd.DataFrame(data11[['Time(sec)_','560.11','777.013']])

fig = px.line(df_20200612_test7_1_03_EPD, x="Time(sec)_", y=["560.11", "777.013"], title="20200612_test7_1_0.3_EPD")
fig.show()
# Out:
# <div>
#
#
#             <div id="833bcb24-a321-418f-b3dd-16da7006b265" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("833bcb24-a321-418f-b3dd-16da7006b265")) {
#                     Plotly.newPlot(
#                         '833bcb24-a321-418f-b3dd-16da7006b265',
# ...

# %%
data12 = pd.read_csv('C:/Users/com/Desktop/2020-06-12 TES OES CSV/2020-06-12_16h21m20s_test8_1_0.6__condition changed and temp 650.f_oes.csv')
df_20200612_test8_1_06_EPD = pd.DataFrame(data12[['Time(sec)_','560.11','777.013']])

fig = px.line(df_20200612_test8_1_06_EPD, x="Time(sec)_", y=["560.11", "777.013"], title="20200612_test8_1_0.6_EPD")
fig.show()
# Out:
# <div>
#
#
#             <div id="23935396-2b0a-4df1-b798-4a3b5edeb426" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("23935396-2b0a-4df1-b798-4a3b5edeb426")) {
#                     Plotly.newPlot(
#                         '23935396-2b0a-4df1-b798-4a3b5edeb426',
# ...
